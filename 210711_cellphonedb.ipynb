# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(100)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib as mpl
mpl.rcParams['figure.facecolor'] = (1,1,1,1)
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

pd.set_option('display.max_columns', 80)

# %%
df = pd.read_csv('cellphonedb/210711_merged_thymoma_MG21.22.23.03/out/significant_means.txt', sep='\t')

# %%
df
# Out:
#      id_cp_interaction              interacting_pair  \
# 0      CPI-CS0BCDC40FC              BMR1A_AVR2B_BMP4
# 1      CPI-SC0EACF2D60          COL26A1_a1b1 complex
# 2      CPI-SC0EAF80261           SEMA7A_a1b1 complex
# 3      CPI-CS085E95BC1  IL1 receptor inhibitor_IL1RN
# 4      CPI-SC0CA7B34A5           COL5A2_a2b1 complex
# ...                ...                           ...
# 1255   CPI-SS01BCB9360                    NCAM1_BDNF
# 1256   CPI-SS0BA3A1C3A                     NGFR_NTF4
# 1257   CPI-SS0C23EF34B                    NCAM1_GDNF
# 1258   CPI-SS054D158CC                     NTRK1_GRN
# 1259   CPI-SS0FF51A757              TNFSF18_TNFRSF18
#
#                            partner_a             partner_b           gene_a  \
# 0                complex:BMR1A_AVR2B         simple:P12644              NaN
# 1                      simple:Q96A83  complex:a1b1 complex  ENSG00000160963
# 2                      simple:O75326  complex:a1b1 complex  ENSG00000138623
# ...

# %%
df.columns
# Out:
# Index(['id_cp_interaction', 'interacting_pair', 'partner_a', 'partner_b',
#        'gene_a', 'gene_b', 'secreted', 'receptor_a', 'receptor_b',
#        'annotation_strategy',
#        ...
#        'pDC|aa CD8 T cell (I)', 'pDC|aa CD8 T cell (II)', 'pDC|cDC1',
#        'pDC|cDC2', 'pDC|cTEC', 'pDC|gd T cell', 'pDC|mTEC (I)',
#        'pDC|mTEC (II)', 'pDC|nmTEC', 'pDC|pDC'],
#       dtype='object', length=2413)

# %%
list_meta = ['id_cp_interaction', 'interacting_pair', 'partner_a', 'partner_b',
       'gene_a', 'gene_b', 'secreted', 'receptor_a', 'receptor_b',
       'annotation_strategy', 'is_integrin', 'rank']
list_pair = [x for x in df.columns if not x in list_meta]

df = df[df[list_pair].sum(axis=1) > 0]

# %%
df.loc[df[list_pair].max(axis=1).sort_values(ascending=False).index]
# Out:
#      id_cp_interaction          interacting_pair                   partner_a  \
# 584    CPI-SS0ABC5C1B8                  CD74_MIF               simple:P04233
# 582    CPI-SS09808DEAE                  CD74_APP               simple:P04233
# 583    CPI-SS0302E8E8F                 CD74_COPA               simple:P04233
# 355    CPI-SS0EF0750A7              HLA-DRB1_OGN              simple:HLADRB1
# 503    CPI-SS01946BE5C               C5AR1_RPS19               simple:P21730
# ...                ...                       ...                         ...
# 925    CPI-CS091BF99D0  ACVR_1A2A receptor_INHBA  complex:ACVR_1A2A receptor
# 112    CPI-SC001669E22          GDF11_TGFR_AVR2A               simple:O95390
# 959    CPI-SC0B066E03C      COL4A6_a11b1 complex               simple:Q14031
# 1115   CPI-SS0D782F60B                 WNT4_FZD8               simple:P56705
# 995    CPI-SC05565E8CE      COL4A6_a10b1 complex               simple:Q14031
#
# ...

# %%
for pos,row in df.loc[df[list_pair].max(axis=1).sort_values(ascending=False).index].iterrows():
    pair = row['interacting_pair']
    print(pair)
    r = row[list_pair] 
    r = r[r > 0]
    print(r.sort_values(ascending=False).head())
    print()
# Out:
# CD74_MIF
# Naive B cell|DN T cell                4.036
# Memory B cell (II)|DN T cell          3.977
# Unswitched memory B cell|DN T cell    3.954
# GC B cell|DN T cell                   3.942
# Memory B cell (I)|DN T cell           3.941
# Name: 584, dtype: object
#
# CD74_APP
# Naive B cell|mTEC (II)                3.828
# Naive B cell|cTEC                     3.809
# Memory B cell (II)|mTEC (II)          3.768
# Memory B cell (II)|cTEC               3.749
# Unswitched memory B cell|mTEC (II)    3.745
# Name: 582, dtype: object
#
# CD74_COPA
# Naive B cell|Monocyte (CD14)          2.978
# Naive B cell|nmTEC                     2.96
# Naive B cell|Monocyte (CD16)          2.946
# Naive B cell|pDC                       2.92
# Memory B cell (II)|Monocyte (CD14)    2.918
# Name: 583, dtype: object
#
# HLA-DRB1_OGN
# cDC2|Tumor associated fibroblast               2.727
# cDC1|Tumor associated fibroblast               2.475
# Macrophage|Tumor associated fibroblast         2.275
# ...

# %%
r = row[list_pair] 
r = r[r > 0]
print(r.sort_values(ascending=False).head().index)
# Out:
# Index(['nmTEC|nmTEC'], dtype='object')
